# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/TransR/Model/OpenKE')

# %%
# !python Test.py
# Out:
# Input Files Path : ./benchmarks/lastfm/
# The total of test triples is 26244.
# The total of valid triples is 26243.
# 100% 26244/26244 [01:11<00:00, 366.53it/s]
# no type constraint results:
# metric:			 MRR 		 MR 		 hit@10 	 hit@3  	 hit@1
# l(raw):			 0.032117 	 1819.075562 	 0.077313 	 0.024615 	 0.004992
# r(raw):			 0.041634 	 1447.888794 	 0.108711 	 0.023320 	 0.005220
# averaged(raw):		 0.036876 	 1633.482178 	 0.093012 	 0.023967 	 0.005106
#
# l(filter):		 0.090908 	 1653.973145 	 0.195854 	 0.097546 	 0.035399
# r(filter):		 0.122923 	 1420.323730 	 0.262879 	 0.137250 	 0.052241
# averaged(filter):	 0.106916 	 1537.148438 	 0.229367 	 0.117398 	 0.043820
# 0.229367
# Results for lastfm_v1.ckpt have been saved to /content/drive/My Drive/TransR/Result/lastfm_v1_test_results.txt.
# 100% 26244/26244 [01:11<00:00, 369.26it/s]
# no type constraint results:
# metric:			 MRR 		 MR 		 hit@10 	 hit@3  	 hit@1
# l(raw):			 0.036871 	 1107.221924 	 0.076894 	 0.030979 	 0.010898
# ...

# %%
# !python Train_v1.py
# Out:
# Input Files Path : ./benchmarks/lastfm/
# The toolkit is importing datasets.
# The total of relations is 4.
# The total of entities is 29242.
# The total of train triples is 209948.
# Input Files Path : ./benchmarks/lastfm/
# The total of test triples is 26244.
# The total of valid triples is 26243.
# Finish initializing...
# Epoch 0 | loss: 730.911799: 100% 1/1 [00:02<00:00,  2.38s/it]
# Finish initializing...
# Epoch 9 | loss: 27.637401:   2% 10/500 [01:02<50:46,  6.22s/it]
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/TransR/Model/OpenKE/Train_v1.py", line 103, in <module>
#     trainer.run()
#   File "/content/drive/MyDrive/TransR/Model/OpenKE/openke/config/Trainer.py", line 93, in run
#     loss = self.train_one_step(data)
#   File "/content/drive/MyDrive/TransR/Model/OpenKE/openke/config/Trainer.py", line 52, in train_one_step
#     loss.backward()
#   File "/usr/local/lib/python3.10/dist-packages/torch/_tensor.py", line 492, in backward
# ...

# %%
# !python Train_v2.py
# Out:
# Input Files Path : ./benchmarks/lastfm/
# The toolkit is importing datasets.
# The total of relations is 4.
# The total of entities is 29242.
# The total of train triples is 209948.
# Input Files Path : ./benchmarks/lastfm/
# The total of test triples is 26244.
# The total of valid triples is 26243.
# Finish initializing...
# Epoch 0 | loss: 1465.843529: 100% 1/1 [00:04<00:00,  4.48s/it]
# Finish initializing...
# Epoch 9 | loss: 111.615319: 100% 10/10 [01:08<00:00,  6.80s/it]
# 100% 26244/26244 [01:02<00:00, 421.27it/s]
# no type constraint results:
# metric:			 MRR 		 MR 		 hit@10 	 hit@3  	 hit@1
# l(raw):			 0.036871 	 1107.221924 	 0.076894 	 0.030979 	 0.010898
# r(raw):			 0.055334 	 1229.536987 	 0.132868 	 0.047249 	 0.013679
# averaged(raw):		 0.046102 	 1168.379395 	 0.104881 	 0.039114 	 0.012289
#
# l(filter):		 0.064482 	 982.845093 	 0.134316 	 0.061881 	 0.025644
# r(filter):		 0.097246 	 1207.619019 	 0.193835 	 0.099718 	 0.044848
# ...

# %%
# !python Train_v3.py
# Out:
# Input Files Path : ./benchmarks/lastfm/
# The toolkit is importing datasets.
# The total of relations is 4.
# The total of entities is 29242.
# The total of train triples is 209948.
# Input Files Path : ./benchmarks/lastfm/
# The total of test triples is 26244.
# The total of valid triples is 26243.
# Finish initializing...
# Epoch 0 | loss: 1839.316546: 100% 1/1 [00:03<00:00,  3.75s/it]
# Finish initializing...
# Epoch 9 | loss: 219.498091: 100% 10/10 [33:53<00:00, 203.37s/it]
#   0% 0/26244 [00:00<?, ?it/s]

# %%
# !python Train_v4.py
# Out:
# Input Files Path : ./benchmarks/lastfm/
# The toolkit is importing datasets.
# The total of relations is 4.
# The total of entities is 29242.
# The total of train triples is 209948.
# Input Files Path : ./benchmarks/lastfm/
# The total of test triples is 26244.
# The total of valid triples is 26243.
# Finish initializing...
# Epoch 0 | loss: 589.295694: 100% 1/1 [00:01<00:00,  1.83s/it]
# Finish initializing...
# Epoch 499 | loss: 7.079691: 100% 500/500 [45:05<00:00,  5.41s/it]
# 100% 26244/26244 [01:07<00:00, 388.84it/s]
# no type constraint results:
# metric:			 MRR 		 MR 		 hit@10 	 hit@3  	 hit@1
# l(raw):			 0.032536 	 1757.053223 	 0.077923 	 0.024996 	 0.005220
# r(raw):			 0.043015 	 1449.765259 	 0.110616 	 0.025644 	 0.005868
# averaged(raw):		 0.037776 	 1603.409180 	 0.094269 	 0.025320 	 0.005544
#
# l(filter):		 0.090825 	 1591.970581 	 0.196388 	 0.097546 	 0.034636
# r(filter):		 0.126986 	 1422.209839 	 0.265737 	 0.139537 	 0.056051
# ...

# %%
# !python Test.py
# Out:
# Input Files Path : ./benchmarks/lastfm/
# The total of test triples is 26244.
# The total of valid triples is 26243.
# 100% 26244/26244 [01:04<00:00, 405.63it/s]
# no type constraint results:
# metric:			 MRR 		 MR 		 hit@10 	 hit@3  	 hit@1
# l(raw):			 0.037464 	 1066.679443 	 0.079218 	 0.030255 	 0.011241
# r(raw):			 0.054927 	 1223.646973 	 0.135345 	 0.045572 	 0.013222
# averaged(raw):		 0.046196 	 1145.163208 	 0.107282 	 0.037913 	 0.012231
#
# l(filter):		 0.065726 	 942.409668 	 0.135498 	 0.062414 	 0.026482
# r(filter):		 0.096735 	 1201.771729 	 0.199703 	 0.099223 	 0.043210
# averaged(filter):	 0.081230 	 1072.090698 	 0.167600 	 0.080818 	 0.034846
# 0.167600
# Results have been saved.
